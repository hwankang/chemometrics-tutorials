# %% [markdown]
# <a href="https://colab.research.google.com/github/hwankang/chemometrics-tutorials/blob/master/12_(mon)_12_11_00_pm_B_NIR_savgol__filter_len_11_polyorder_2_deriv_2_n_24_R2%3D_minius_0_2319.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import plotly.graph_objects as go
import plotly.express as px

from scipy.signal import savgol_filter

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import KFold, cross_val_predict
from sklearn.cross_decomposition import PLSRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
filename_a='/content/drive/MyDrive/machine_learning/B_NIR_DATA_csv.csv'
import pandas as pd
data_a = pd.read_csv(filename_a,header=0, 
                   encoding="unicode-escape")
data=data_a

# %%
data.head()
# Out:
#    Unnamed: 0  ¸ðµ¨ Æ÷ÇÔ  Y_B  899.9280058  900.2520706  900.5763689  \
# 0           1       True  2.0     0.276093     0.279368     0.282974
# 1           2       True  1.8     0.199544     0.202455     0.206198
# 2           3       True  6.7     0.306803     0.309845     0.313508
# 3           4       True  6.2     0.286879     0.290392     0.294110
# 4           5      False  5.1     0.253218     0.256407     0.260161
#
#    900.9009009  901.2256669  901.5506671  901.8759019  ...  2477.700694  \
# 0     0.283645     0.283141     0.282718     0.281553  ...     2.949425
# 1     0.207755     0.208028     0.207398     0.205435  ...     2.981332
# 2     0.314680     0.314671     0.314172     0.312433  ...     2.991938
# 3     0.294774     0.294035     0.293060     0.291292  ...     2.991402
# 4     0.261418     0.261547     0.261116     0.259408  ...     3.004459
#
#    2480.15873  2482.621648  2485.089463  2487.562189  2490.039841  \
# 0    2.949937     2.940435     2.930193     2.927044     2.926591
# 1    2.984826     2.975499     2.964666     2.964128     2.967567
# 2    2.992541     2.984488     2.976776     2.975918     2.973828
# 3    2.990624     2.980183     2.970664     2.967151     2.961850
# 4    3.005398     3.000151     2.995331     2.997660     2.999729
#
#    2492.522433  2495.00998  2497.502498      2500
# 0     2.917971    2.911627     2.911584  2.909855
# 1     2.960830    2.954538     2.956946  2.955335
# 2     2.963011    2.955492     2.954702  2.949301
# 3     2.948892    2.939125     2.938542  2.934796
# 4     2.992129    2.987290     2.988690  2.987576
#
# [5 rows x 1782 columns]

# %%
xlen, ylen=data.shape
xlen, ylen
# Out:
# (624, 1782)

# %%
xx2=data.columns[1]
xx2
# Out:
# '¸ðµ¨ Æ÷ÇÔ'

# %%
data[xx2].values[4]==False
# Out:
# True

# %%
#a1=[]
#xlen-6
#for i in range(0,xlen):
#    if data[xx2].values[i]==Fal:
#        a1.append(i)
#data2=data.drop(a1,axis=0)
data2=data

# %%
xdata=list(data2.columns)[3:]

# %%
y=data2['Y_B'].values
X=data2.values[:,3:]
X
y
# Out:
# array([ 2.   ,  1.8  ,  6.7  ,  6.2  ,  5.1  , 13.7  ,  0.   ,  0.   ,
#         0.   ,  0.   ,  0.   ,  0.   ,  2.2  ,  2.4  ,  4.   ,  7.8  ,
#         9.4  ,  8.2  ,  0.   ,  0.   ,  0.   ,  0.   ,  0.   ,  0.   ,
#         3.7  ,  3.6  ,  5.7  ,  7.8  ,  6.4  , 11.9  ,  0.   ,  0.   ,
#         0.   ,  0.   ,  0.   ,  0.   ,  3.7  ,  1.8  ,  6.   ,  7.9  ,
#         6.5  , 12.2  ,  0.   ,  0.   ,  0.   ,  0.   ,  0.   ,  0.   ,
#         3.8  ,  3.1  ,  3.7  ,  8.2  ,  9.8  ,  7.   ,  0.   ,  0.   ,
#         0.   ,  0.   ,  0.   ,  0.   ,  3.9  ,  3.7  ,  6.1  ,  8.5  ,
#         9.7  , 12.6  ,  0.   ,  0.   ,  0.   ,  0.   ,  0.   ,  0.   ,
#         3.5  ,  3.7  ,  5.5  ,  7.7  ,  9.4  , 10.9  ,  0.   ,  0.   ,
#         0.   ,  0.   ,  0.   ,  0.   ,  0.6  ,  2.   ,  3.3  ,  5.4  ,
#         9.7  ,  7.1  ,  0.   ,  0.   ,  0.   ,  0.   ,  0.   ,  0.   ,
#         2.   ,  1.8  ,  6.7  ,  6.2  ,  5.1  , 13.7  ,  0.   ,  0.   ,
#         0.   ,  0.   ,  0.   ,  0.   ,  2.2  ,  2.4  ,  4.   ,  7.8  ,
#         9.4  ,  8.2  ,  0.   ,  0.   ,  0.   ,  0.   ,  0.   ,  0.   ,
#         3.7  ,  3.6  ,  5.7  ,  7.8  ,  6.4  , 11.9  ,  0.   ,  0.   ,
#         0.   ,  0.   ,  0.   ,  0.   ,  3.7  ,  1.8  ,  6.   ,  7.9  ,
#         6.5  , 12.2  ,  0.   ,  0.   ,  0.   ,  0.   ,  0.   ,  0.   ,
#         3.8  ,  3.1  ,  3.7  ,  8.2  ,  9.8  ,  7.   ,  0.   ,  0.   ,
#         0.   ,  0.   ,  0.   ,  0.   ,  3.9  ,  3.7  ,  6.1  ,  8.5  ,
#         9.7  , 12.6  ,  0.   ,  0.   ,  0.   ,  0.   ,  0.   ,  0.   ,
#         3.5  ,  3.7  ,  5.5  ,  7.7  ,  9.4  , 10.9  ,  0.   ,  0.   ,
#         0.   ,  0.   ,  0.   ,  0.   ,  0.6  ,  2.   ,  3.3  ,  5.4  ,
#         9.7  ,  7.1  ,  0.   ,  0.   ,  0.   ,  0.   ,  0.   ,  0.   ,
#         3.256,  3.185,  5.303,  7.076,  7.907, 10.775,  0.   ,  0.   ,
#         0.   ,  0.   ,  0.   ,  0.   ,  2.921,  3.19 ,  5.359,  7.221,
#         8.563, 10.755,  0.   ,  0.   ,  0.   ,  0.   ,  0.   ,  0.   ,
#         3.102,  2.792,  5.231,  7.233,  8.376, 10.826,  0.   ,  0.   ,
#         0.   ,  0.   ,  0.   ,  0.   ,  3.154,  2.9  ,  5.334,  7.223,
#         8.483, 10.932,  0.   ,  0.   ,  0.   ,  0.   ,  0.   ,  0.   ,
#         3.128,  3.234,  5.305,  7.323,  8.33 , 10.531,  0.   ,  0.   ,
#         0.   ,  0.   ,  0.   ,  0.   ,  2.986,  2.901,  5.401,  7.02 ,
#         8.24 , 10.469,  0.   ,  0.   ,  0.   ,  0.   ,  0.   ,  0.   ,
#         3.216,  3.195,  5.374,  7.185,  8.558, 10.598,  0.   ,  0.   ,
#         0.   ,  0.   ,  0.   ,  0.   ,  3.26 ,  3.177,  5.172,  7.359,
#         8.419, 10.668,  0.   ,  0.   ,  0.   ,  0.   ,  0.   ,  0.   ,
#         3.256,  3.185,  5.303,  7.076,  7.907, 10.775,  0.   ,  0.   ,
#         0.   ,  0.   ,  0.   ,  0.   ,  2.921,  3.19 ,  5.359,  7.221,
#         8.563, 10.755,  0.   ,  0.   ,  0.   ,  0.   ,  0.   ,  0.   ,
#         3.102,  2.792,  5.231,  7.233,  8.376, 10.826,  0.   ,  0.   ,
#         0.   ,  0.   ,  0.   ,  0.   ,  3.154,  2.9  ,  5.334,  7.223,
#         8.483, 10.932,  0.   ,  0.   ,  0.   ,  0.   ,  0.   ,  0.   ,
#         3.128,  3.234,  5.305,  7.323,  8.33 , 10.531,  0.   ,  0.   ,
#         0.   ,  0.   ,  0.   ,  0.   ,  2.986,  2.901,  5.401,  7.02 ,
#         8.24 , 10.469,  0.   ,  0.   ,  0.   ,  0.   ,  0.   ,  0.   ,
#         3.216,  3.195,  5.374,  7.185,  8.558, 10.598,  0.   ,  0.   ,
#         0.   ,  0.   ,  0.   ,  0.   ,  3.26 ,  3.177,  5.172,  7.359,
#         8.419, 10.668,  0.   ,  0.   ,  0.   ,  0.   ,  0.   ,  0.   ,
#         1.077,  0.771,  8.384, 11.333, 13.737,  1.906,  0.   ,  0.   ,
#         0.   ,  0.   ,  0.   ,  0.   ,  5.242,  5.168,  7.542,  9.867,
#        11.494, 13.964,  0.   ,  0.   ,  0.   ,  0.   ,  0.   ,  0.   ,
#         5.236,  4.871,  7.49 , 10.044, 11.46 , 13.886,  0.   ,  0.   ,
#         0.   ,  0.   ,  0.   ,  0.   ,  4.75 ,  4.964,  7.757,  9.855,
#        11.179, 14.043,  0.   ,  0.   ,  0.   ,  0.   ,  0.   ,  0.   ,
#         4.7  ,  4.587,  7.42 , 10.527, 10.943, 14.415,  0.   ,  0.   ,
#         0.   ,  0.   ,  0.   ,  0.   ,  4.571,  4.653,  7.257, 10.015,
#        11.99 , 14.429,  0.   ,  0.   ,  0.   ,  0.   ,  0.   ,  0.   ,
#         4.962,  4.58 ,  7.415,  9.556, 11.293, 14.139,  0.   ,  0.   ,
#         0.   ,  0.   ,  0.   ,  0.   ,  5.332,  5.604,  7.469, 10.453,
#        12.409, 16.332,  0.   ,  0.   ,  0.   ,  0.   ,  0.   ,  0.   ,
#         1.077,  0.771,  8.384, 11.333, 13.737,  1.906,  0.   ,  0.   ,
#         0.   ,  0.   ,  0.   ,  0.   ,  5.242,  5.168,  7.542,  9.867,
#        11.494, 13.964,  0.   ,  0.   ,  0.   ,  0.   ,  0.   ,  0.   ,
#         5.236,  4.871,  7.49 , 10.044, 11.46 , 13.886,  0.   ,  0.   ,
#         0.   ,  0.   ,  0.   ,  0.   ,  4.75 ,  4.964,  7.757,  9.855,
#        11.179, 14.043,  0.   ,  0.   ,  0.   ,  0.   ,  0.   ,  0.   ,
#         4.7  ,  4.587,  7.42 , 10.527, 10.943, 14.415,  0.   ,  0.   ,
#         0.   ,  0.   ,  0.   ,  0.   ,  4.571,  4.653,  7.257, 10.015,
#        11.99 , 14.429,  0.   ,  0.   ,  0.   ,  0.   ,  0.   ,  0.   ,
#         4.962,  4.58 ,  7.415,  9.556, 11.293, 14.139,  0.   ,  0.   ,
#         0.   ,  0.   ,  0.   ,  0.   ,  5.332,  5.604,  7.469, 10.453,
#        12.409, 16.332,  0.   ,  0.   ,  0.   ,  0.   ,  0.   ,  0.   ,
#         6.9  ,  6.4  ,  8.6  , 10.4  , 11.7  , 13.1  ,  9.6  ,  9.7  ,
#        11.8  , 13.3  , 13.9  , 16.1  ,  7.1  ,  6.6  ,  8.6  , 10.6  ,
#        11.6  , 13.5  ,  8.4  ,  8.2  , 10.2  , 11.7  , 12.7  , 14.9  ,
#         7.1  ,  6.9  ,  9.2  , 10.9  , 11.9  , 13.7  ,  8.4  ,  8.3  ,
#        10.5  , 12.3  , 13.3  , 15.3  ,  6.8  ,  6.6  ,  8.8  , 10.8  ,
#        11.9  , 13.6  ,  8.5  ,  8.6  , 10.8  , 12.2  , 13.4  , 15.8  ])

# %%
X.shape, y.shape
# Out:
# ((624, 1779), (624,))

# %%
with plt.style.context('ggplot'):
    plt.plot(xdata, X.T)
    plt.xlabel("Wavelengths (nm)")
    plt.ylabel("Absorbance")

# %%
#X2 = savgol_filter(X, 17, polyorder=2, deriv=2)
#X2 = savgol_filter(X, 17, polyorder=2, deriv=1)
#X2 = savgol_filter(X, 571, polyorder=2, deriv=2)
X2 = savgol_filter(X, 11, polyorder=2, deriv=2)
#X2=X

# %%
def optimise_pls_cv(X, y, n_comp):
    # Define PLS object
    pls = PLSRegression(n_components=n_comp)

    # Cross-validation
    y_cv = cross_val_predict(pls, X, y, cv=10)

    # Calculate scores
    r2 = r2_score(y, y_cv)
    mse = mean_squared_error(y, y_cv)
    rpd = y.std()/np.sqrt(mse)
    
    return (y_cv, r2, mse, rpd)

# %%
r2s = []
mses = []
rpds = []
xticks = np.arange(1, 41)
for n_comp in xticks:
    y_cv, r2, mse, rpd = optimise_pls_cv(X2, y, n_comp)
    r2s.append(r2)
    mses.append(mse)
    rpds.append(rpd)

# %%
# Plot the mses
def plot_metrics(vals, ylabel, objective):
    with plt.style.context('ggplot'):
        plt.plot(xticks, np.array(vals), '-v', color='blue', mfc='blue')
        if objective=='min':
            idx = np.argmin(vals)
        else:
            idx = np.argmax(vals)
        plt.plot(xticks[idx], np.array(vals)[idx], 'P', ms=10, mfc='red')

        plt.xlabel('Number of PLS components')
        plt.xticks = xticks
        plt.ylabel(ylabel)
        plt.title('PLS')

    plt.show()

# %%
plot_metrics(mses, 'MSE', 'min')

# %%
plot_metrics(rpds, 'RPD', 'max')

# %%
plot_metrics(r2s, 'R2', 'max')

# %%
y_cv, r2, mse, rpd = optimise_pls_cv(X2, y, 1)

# %%
print('R2: %0.4f, MSE: %0.4f, RPD: %0.4f' %(r2, mse, rpd))
# Out:
# R2: -0.2319, MSE: 25.9976, RPD: 0.9010

# %%
y_cv, r2, mse, rpd = optimise_pls_cv(X2, y, 8)
print('R2: %0.4f, MSE: %0.4f, RPD: %0.4f' %(r2, mse, rpd))
# Out:
# R2: 0.2610, MSE: 9.1609, RPD: 1.1632

# %%
y_cv, r2, mse, rpd = optimise_pls_cv(X2, y, 9)
print('R2: %0.4f, MSE: %0.4f, RPD: %0.4f' %(r2, mse, rpd))
# Out:
# R2: 0.3019, MSE: 8.6538, RPD: 1.1968

# %%
y_cv, r2, mse, rpd = optimise_pls_cv(X2, y, 10)
print('R2: %0.4f, MSE: %0.4f, RPD: %0.4f' %(r2, mse, rpd))
# Out:
# R2: 0.4511, MSE: 6.8045, RPD: 1.3497

# %%
y_cv, r2, mse, rpd = optimise_pls_cv(X2, y, 11)
print('R2: %0.4f, MSE: %0.4f, RPD: %0.4f' %(r2, mse, rpd))
# Out:
# R2: 0.5925, MSE: 5.0518, RPD: 1.5664

# %%
y_cv, r2, mse, rpd = optimise_pls_cv(X2, y, 25)
print('R2: %0.4f, MSE: %0.4f, RPD: %0.4f' %(r2, mse, rpd))
# Out:
# R2: 0.8984, MSE: 1.2598, RPD: 3.1369

# %%
plt.figure(figsize=(6, 6))
with plt.style.context('ggplot'):
    plt.scatter(y, y_cv, color='red')
    plt.plot(y, y, '-g', label='Expected regression line')
    z = np.polyfit(y, y_cv, 1)
    plt.plot(np.polyval(z, y), y, color='blue', label='Predicted regression line')
    plt.xlabel('Actual')
    plt.ylabel('Predicted')
    plt.legend()
    plt.plot()

# %%
y_cv, r2, mse, rpd = optimise_pls_cv(X2, y, 7)
print('R2: %0.4f, MSE: %0.4f, RPD: %0.4f' %(r2, mse, rpd))
# Out:
# R2: 0.8451, MSE: 1.9196, RPD: 2.5411

# %%
plt.figure(figsize=(6, 6))
with plt.style.context('ggplot'):
    plt.scatter(y, y_cv, color='red')
    plt.plot(y, y, '-g', label='Expected regression line')
    z = np.polyfit(y, y_cv, 1)
    plt.plot(np.polyval(z, y), y, color='blue', label='Predicted regression line')
    plt.xlabel('Actual')
    plt.ylabel('Predicted')
    plt.legend()
    plt.plot()

# %%
y_cv, r2, mse, rpd = optimise_pls_cv(X2, y, 9)
print('R2: %0.4f, MSE: %0.4f, RPD: %0.4f' %(r2, mse, rpd))

# %%
X2 = savgol_filter(X, 17, polyorder=2, deriv=2)
#X2 = savgol_filter(X, 17, polyorder=2, deriv=1)
#X2=X

# %%
def optimise_pls_cv(X, y, n_comp):
    # Define PLS object
    pls = PLSRegression(n_components=n_comp)

    # Cross-validation
    y_cv = cross_val_predict(pls, X, y, cv=10)

    # Calculate scores
    r2 = r2_score(y, y_cv)
    mse = mean_squared_error(y, y_cv)
    rpd = y.std()/np.sqrt(mse)
    
    return (y_cv, r2, mse, rpd)

# %%
r2s = []
mses = []
rpds = []
xticks = np.arange(1, 41)
for n_comp in xticks:
    y_cv, r2, mse, rpd = optimise_pls_cv(X2, y, n_comp)
    r2s.append(r2)
    mses.append(mse)
    rpds.append(rpd)

# %%
# Plot the mses
def plot_metrics(vals, ylabel, objective):
    with plt.style.context('ggplot'):
        plt.plot(xticks, np.array(vals), '-v', color='blue', mfc='blue')
        if objective=='min':
            idx = np.argmin(vals)
        else:
            idx = np.argmax(vals)
        plt.plot(xticks[idx], np.array(vals)[idx], 'P', ms=10, mfc='red')

        plt.xlabel('Number of PLS components')
        plt.xticks = xticks
        plt.ylabel(ylabel)
        plt.title('PLS')

    plt.show()

# %%
plot_metrics(mses, 'MSE', 'min')

# %%
plot_metrics(rpds, 'RPD', 'max')

# %%
plot_metrics(r2s, 'R2', 'max')

# %%
y_cv, r2, mse, rpd = optimise_pls_cv(X2, y, 6)
print('R2: %0.4f, MSE: %0.4f, RPD: %0.4f' %(r2, mse, rpd))
# Out:
# R2: 0.8275, MSE: 2.1378, RPD: 2.4080

# %%
y_cv, r2, mse, rpd = optimise_pls_cv(X2, y, 7)

# %%
print('R2: %0.4f, MSE: %0.4f, RPD: %0.4f' %(r2, mse, rpd))
# Out:
# R2: 0.8451, MSE: 1.9196, RPD: 2.5411

# %%
y_cv, r2, mse, rpd = optimise_pls_cv(X2, y, 9)
print('R2: %0.4f, MSE: %0.4f, RPD: %0.4f' %(r2, mse, rpd))
# Out:
# R2: 0.8510, MSE: 1.8474, RPD: 2.5903

# %%
y_cv, r2, mse, rpd = optimise_pls_cv(X2, y, 9)
print('R2: %0.4f, MSE: %0.4f, RPD: %0.4f' %(r2, mse, rpd))
# Out:
# R2: 0.8510, MSE: 1.8474, RPD: 2.5903

# %%
y_cv, r2, mse, rpd = optimise_pls_cv(X2, y, 10)
print('R2: %0.4f, MSE: %0.4f, RPD: %0.4f' %(r2, mse, rpd))
# Out:
# R2: 0.8476, MSE: 1.8897, RPD: 2.5612

# %%
y_cv, r2, mse, rpd = optimise_pls_cv(X2, y, 11)
print('R2: %0.4f, MSE: %0.4f, RPD: %0.4f' %(r2, mse, rpd))
# Out:
# R2: 0.8457, MSE: 1.9132, RPD: 2.5454

# %%
y_cv, r2, mse, rpd = optimise_pls_cv(X2, y, 12)
print('R2: %0.4f, MSE: %0.4f, RPD: %0.4f' %(r2, mse, rpd))
# Out:
# R2: 0.8417, MSE: 1.9625, RPD: 2.5132

# %%
plt.figure(figsize=(6, 6))
with plt.style.context('ggplot'):
    plt.scatter(y, y_cv, color='red')
    plt.plot(y, y, '-g', label='Expected regression line')
    z = np.polyfit(y, y_cv, 1)
    plt.plot(np.polyval(z, y), y, color='blue', label='Predicted regression line')
    plt.xlabel('Actual')
    plt.ylabel('Predicted')
    plt.legend()
    plt.plot()
